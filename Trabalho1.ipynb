# %%
import numpy as np
import pandas as pd

# %%
feature = pd.read_csv('features.txt', delimiter=' ', header=None)
labels = pd.read_csv('activity_labels.txt', delimiter=' ', header=None)

# %%
feature
# Out:
#        0                                     1
# 0      1                     tBodyAcc-mean()-X
# 1      2                     tBodyAcc-mean()-Y
# 2      3                     tBodyAcc-mean()-Z
# 3      4                      tBodyAcc-std()-X
# 4      5                      tBodyAcc-std()-Y
# 5      6                      tBodyAcc-std()-Z
# 6      7                      tBodyAcc-mad()-X
# 7      8                      tBodyAcc-mad()-Y
# 8      9                      tBodyAcc-mad()-Z
# 9     10                      tBodyAcc-max()-X
# 10    11                      tBodyAcc-max()-Y
# 11    12                      tBodyAcc-max()-Z
# 12    13                      tBodyAcc-min()-X
# 13    14                      tBodyAcc-min()-Y
# 14    15                      tBodyAcc-min()-Z
# 15    16                        tBodyAcc-sma()
# 16    17                   tBodyAcc-energy()-X
# 17    18                   tBodyAcc-energy()-Y
# 18    19                   tBodyAcc-energy()-Z
# ...

# %% [markdown]
# <h1> Import dos algoritimos </h1>

# %%
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import KFold
from sklearn.metrics import *

# %% [markdown]
# <h4>Verificar se precisa balancear os dados</h4>

# %%
x_train = pd.read_csv('train/X_train.txt', sep=r"\s+", header=None)
y_train = pd.read_csv('train/y_train.txt', sep=r"\s+", header=None)

# %%
for x in labels.get_values():
    print x
# Out:
# [1L 'WALKING']
# [2L 'WALKING_UPSTAIRS']
# [3L 'WALKING_DOWNSTAIRS']
# [4L 'SITTING']
# [5L 'STANDING']
# [6L 'LAYING']

# %%
WALKING=0
WALKING_UPSTAIRS=0
WALKING_DOWNSTAIRS=0
SITTING=0
STANDING=0
LAYING=0

# %%
valores_y = y_train.values
for x in valores_y:
    if x == 1:
        WALKING+=1
    if x == 2:
        WALKING_UPSTAIRS+=1
    if x == 3:
        WALKING_DOWNSTAIRS+=1
    if x == 4:
        SITTING+=1
    if x == 5:
        STANDING+=1
    if x == 6:
        LAYING+=1

LAYING   ,STANDING,SITTING,WALKING_DOWNSTAIRS,WALKING_UPSTAIRS,WALKING
# Out:
# (1407, 1374, 1286, 986, 1073, 1226)
